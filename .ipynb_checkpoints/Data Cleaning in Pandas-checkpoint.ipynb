# %% [markdown]
# # Data Cleaning in Pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"Customer Call List.xlsx")

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 17        1018      Clark         Kent    7066950392
# 18        1019      Creed       Braton           N/a
# 19        1020     Anakin    Skywalker  876|678|3469
# 20        1020     Anakin    Skywalker  876|678|3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N
# 20            910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 0                True
# 1               False
# 2                True
# 3                True
# 4                True
# 5                True
# 6               False
# 7               False
# 8               False
# 9                True
# 10               True
# 11               True
# 12              False
# 13              False
# 14              False
# 15              False
# 16              False
# 17               True
# 18               True
# 19               True
# 20               True

# %%
# Missing value test
for i in df.columns:
    missing_pct = np.mean(df[i].isnull())
    print('{} - {}% is missing'.format(i, missing_pct))
# Out:
# CustomerID - 0.0% is missing
# First_Name - 0.0% is missing
# Last_Name - 0.047619047619047616% is missing
# Phone_Number - 0.09523809523809523% is missing
# Address - 0.0% is missing
# Paying Customer - 0.0% is missing
# Do_Not_Contact - 0.19047619047619047% is missing
# Not_Useful_Column - 0.0% is missing

# %%
# From above testing, we can conclude that there is some data missing
# from some columns such as: Last_name, Phone_Number, and Do_Not_Contact

# This does not check for the values such as N/a etc
# I am not sure about string

# %%
# Removing duplicates from the dataset completely

df.drop_duplicates()
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 17        1018      Clark         Kent    7066950392
# 18        1019      Creed       Braton           N/a
# 19        1020     Anakin    Skywalker  876|678|3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 0                True
# 1               False
# 2                True
# 3                True
# 4                True
# 5                True
# 6               False
# 7               False
# 8               False
# 9                True
# 10               True
# 11               True
# 12              False
# 13              False
# 14              False
# 15              False
# 16              False
# 17               True
# 18               True
# 19               True

# %%
# 1 Row was duplicate as we can observe
# 1020 Anakin Skywalker was dropped from the dataset

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 17        1018      Clark         Kent    7066950392
# 18        1019      Creed       Braton           N/a
# 19        1020     Anakin    Skywalker  876|678|3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 0                True
# 1               False
# 2                True
# 3                True
# 4                True
# 5                True
# 6               False
# 7               False
# 8               False
# 9                True
# 10               True
# 11               True
# 12              False
# 13              False
# 14              False
# 15              False
# 16              False
# 17               True
# 18               True
# 19               True

# %%
# Removing the unwanted columns such as Not_Useful_Column

# %%
df.drop(columns = "Not_Useful_Column", inplace = True)
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\1082106222.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns = "Not_Useful_Column", inplace = True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 17        1018      Clark         Kent    7066950392
# 18        1019      Creed       Braton           N/a
# 19        1020     Anakin    Skywalker  876|678|3469
#
#                                   Address Paying Customer Do_Not_Contact
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N

# %%
# Cleaning Last Name column

# %%
# Strip function

df["Last_Name"].str.strip()
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
# Looks like nothings is changes
# Because by default it takes out whitespaces

# %%
df["Last_Name"].str.strip("...")
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11         Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
# Looks like it removed ... now
# Strip removed specified/whitespace from both left and right hand side of the string
# lstrip for left hand side and rstrip for right hand side

# %%
# We can take it out one by one and specify that column value to that specified column
# eg:
# df["Last_Name"] = df["Last_Name"].str.lstrip("...")
# again
# df["Last_Name"] = df["Last_Name"].str.rstrip("_")
# etc

# %%
# Let's try to find something better

# %%
df["Last_Name"] = df["Last_Name"].str.strip("123._/")
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\523691876.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Last_Name"] = df["Last_Name"].str.strip("123._/")

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# 17        1018      Clark        Kent    7066950392
# 18        1019      Creed      Braton           N/a
# 19        1020     Anakin   Skywalker  876|678|3469
#
#                                   Address Paying Customer Do_Not_Contact
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N

# %%
# Problem with this is it will not remove any issue if it is b/w a string eg: Har_sh

# %%
# Let's work with the phone number

# %%
df["Phone_Number"].str.isalnum()
# Out:
# 0     False
# 1     False
# 2       NaN
# 3     False
# 4     False
# 5     False
# 6       NaN
# 7     False
# 8     False
# 9     False
# 10      NaN
# 11      NaN
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17      NaN
# 18    False
# 19    False
# Name: Phone_Number, dtype: object

# %%
df["Phone_Number"].str.replace('[^a-zA-Z0-9]', '')
# Out:
# 0     123-545-5421
# 1     123/643/9775
# 2              NaN
# 3     123-543-2345
# 4     876|678|3469
# 5     304-762-2467
# 6              NaN
# 7     876|678|3469
# 8              N/a
# 9     123-545-5421
# 10             NaN
# 11             NaN
# 12    123-543-2345
# 13    876|678|3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123/643/9775
# 17             NaN
# 18             N/a
# 19    876|678|3469
# Name: Phone_Number, dtype: object

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace('[^a-zA-Z0-9]', '', regex = True)
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\1526765032.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"] = df["Phone_Number"].str.replace('[^a-zA-Z0-9]', '', regex = True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White          NaN
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          NaN
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          NaN
# 11        1012      Harry      Potter          NaN
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# 17        1018      Clark        Kent          NaN
# 18        1019      Creed      Braton           Na
# 19        1020     Anakin   Skywalker   8766783469
#
#                                   Address Paying Customer Do_Not_Contact
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N

# %%
df["Phone_Number"]=df["Phone_Number"].apply(lambda i: str(i))
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\3894540287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"]=df["Phone_Number"].apply(lambda i: str(i))

# %%
df["Phone_Number"] = df["Phone_Number"].apply(lambda i: i[0:3]+'-'+i[3:6]+'-'+i[6:10])
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\2896062999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"] = df["Phone_Number"].apply(lambda i: i[0:3]+'-'+i[3:6]+'-'+i[6:10])

# %%
df["Phone_Number"] = df["Phone_Number"].str.strip('-')
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\874325093.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"] = df["Phone_Number"].str.strip('-')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White           nan
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           nan
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN            Na
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           nan
# 11        1012      Harry      Potter           nan
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent           nan
# 18        1019      Creed      Braton            Na
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace('[nan, Na]', '', regex=True)
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\2278384791.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"] = df["Phone_Number"].str.replace('[nan, Na]', '', regex=True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N

# %%
df["Last_Name"] = df["Last_Name"].apply(lambda x: str(x))
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\1324850998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Last_Name"] = df["Last_Name"].apply(lambda x: str(x))

# %%
df["Last_Name"] = df["Last_Name"].str.replace('nan', '')
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\1637597783.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Last_Name"] = df["Last_Name"].str.replace('nan', '')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N

# %%
df['Address'] = df['Address'].apply(lambda a : str(a))
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\234586599.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Address'] = df['Address'].apply(lambda a : str(a))

# %%
df['Address']
# Out:
# 0                     123 Shire Lane, Shire
# 1                       93 West Main Street
# 2                        298 Drugs Driveway
# 3     980 Paper Avenue, Pennsylvania, 18503
# 4                          123 Dragons Road
# 5                          768 City Parkway
# 6                         1209 South Street
# 7                             98 Clue Drive
# 8                          123 Middle Earth
# 9                25th Main Street, New York
# 10                    612 Shire Lane, Shire
# 11                     2394 Hogwarts Avenue
# 12                         2039 Main Street
# 13                         343 City Parkway
# 14                            214 HR Avenue
# 15                     2395 Hogwarts Avenue
# 16           121 Paper Avenue, Pennsylvania
# 17                          3498 Super Lane
# 18                                      N/a
# 19              910 Tatooine Road, Tatooine
# Name: Address, dtype: object

# %%
df['Address'] = df['Address'].str.replace('N/a', '')
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\1071132623.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Address'] = df['Address'].str.replace('N/a', '')

# %%
df['Address']
# Out:
# 0                     123 Shire Lane, Shire
# 1                       93 West Main Street
# 2                        298 Drugs Driveway
# 3     980 Paper Avenue, Pennsylvania, 18503
# 4                          123 Dragons Road
# 5                          768 City Parkway
# 6                         1209 South Street
# 7                             98 Clue Drive
# 8                          123 Middle Earth
# 9                25th Main Street, New York
# 10                    612 Shire Lane, Shire
# 11                     2394 Hogwarts Avenue
# 12                         2039 Main Street
# 13                         343 City Parkway
# 14                            214 HR Avenue
# 15                     2395 Hogwarts Avenue
# 16           121 Paper Avenue, Pennsylvania
# 17                          3498 Super Lane
# 18
# 19              910 Tatooine Road, Tatooine
# Name: Address, dtype: object

# %%
df["Address"].str.split(',', expand=True)
# Out:
#                        0              1       2
# 0         123 Shire Lane          Shire    None
# 1    93 West Main Street           None    None
# 2     298 Drugs Driveway           None    None
# 3       980 Paper Avenue   Pennsylvania   18503
# 4       123 Dragons Road           None    None
# 5       768 City Parkway           None    None
# 6      1209 South Street           None    None
# 7          98 Clue Drive           None    None
# 8       123 Middle Earth           None    None
# 9       25th Main Street       New York    None
# 10        612 Shire Lane          Shire    None
# 11  2394 Hogwarts Avenue           None    None
# 12      2039 Main Street           None    None
# 13      343 City Parkway           None    None
# 14         214 HR Avenue           None    None
# 15  2395 Hogwarts Avenue           None    None
# 16      121 Paper Avenue   Pennsylvania    None
# 17       3498 Super Lane           None    None
# 18                                 None    None
# 19     910 Tatooine Road       Tatooine    None

# %%
df[["Street_Address", "State", "Zip_Code"]] = df["Address"].str.split(',', expand=True)
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\2350548833.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Street_Address", "State", "Zip_Code"]] = df["Address"].str.split(',', expand=True)
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\2350548833.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Street_Address", "State", "Zip_Code"]] = df["Address"].str.split(',', expand=True)
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\2350548833.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Street_Address", "State", "Zip_Code"]] = df["Address"].str.split(',', expand=True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                                    N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N
#
#           Street_Address          State Zip_Code
# 0         123 Shire Lane          Shire     None
# 1    93 West Main Street           None     None
# 2     298 Drugs Driveway           None     None
# 3       980 Paper Avenue   Pennsylvania    18503
# 4       123 Dragons Road           None     None
# 5       768 City Parkway           None     None
# 6      1209 South Street           None     None
# 7          98 Clue Drive           None     None
# 8       123 Middle Earth           None     None
# 9       25th Main Street       New York     None
# 10        612 Shire Lane          Shire     None
# 11  2394 Hogwarts Avenue           None     None
# 12      2039 Main Street           None     None
# 13      343 City Parkway           None     None
# 14         214 HR Avenue           None     None
# 15  2395 Hogwarts Avenue           None     None
# 16      121 Paper Avenue   Pennsylvania     None
# 17       3498 Super Lane           None     None
# 18                                 None     None
# 19     910 Tatooine Road       Tatooine     None

# %%
df.drop(columns = "Address", inplace = True)
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\698873831.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns = "Address", inplace = True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123-643-9775              No
# 2         1003     Walter       White                             N
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876-678-3469               Y
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 6         1007       Jeff      Winger                            No
# 7         1008   Sherlock      Holmes  876-678-3469               N
# 8         1009    Gandalf                                       Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee                           Yes
# 11        1012      Harry      Potter                             Y
# 12        1013        Don      Draper  123-543-2345             Yes
# 13        1014     Leslie       Knope  876-678-3469             Yes
# 14        1015       Toby  Flenderson  304-762-2467               N
# 15        1016        Ron     Weasley  123-545-5421              No
# 16        1017   Michael        Scott  123-643-9775             Yes
# 17        1018      Clark        Kent                             Y
# 18        1019      Creed      Braton                           N/a
# 19        1020     Anakin   Skywalker  876-678-3469             Yes
#
#    Do_Not_Contact        Street_Address          State Zip_Code
# 0              No        123 Shire Lane          Shire     None
# 1             Yes   93 West Main Street           None     None
# 2             NaN    298 Drugs Driveway           None     None
# 3               Y      980 Paper Avenue   Pennsylvania    18503
# 4              No      123 Dragons Road           None     None
# 5             Yes      768 City Parkway           None     None
# 6              No     1209 South Street           None     None
# 7              No         98 Clue Drive           None     None
# 8             NaN      123 Middle Earth           None     None
# 9              No      25th Main Street       New York     None
# 10             No        612 Shire Lane          Shire     None
# 11            NaN  2394 Hogwarts Avenue           None     None
# 12              N      2039 Main Street           None     None
# 13             No      343 City Parkway           None     None
# 14             No         214 HR Avenue           None     None
# 15              N  2395 Hogwarts Avenue           None     None
# 16             No      121 Paper Avenue   Pennsylvania     None
# 17            NaN       3498 Super Lane           None     None
# 18            Yes                                 None     None
# 19              N     910 Tatooine Road       Tatooine     None

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                                    N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N

# %%
type(df['Address'])
# Out:
# pandas.core.series.Series

# %%
df['Address'].dtypes
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# CustomerID          int64
# First_Name         object
# Last_Name          object
# Phone_Number       object
# Address            object
# Paying Customer    object
# Do_Not_Contact     object
# dtype: object

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                                    N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N

# %%
df['Paying Customer']
# Out:
# 0     Yes
# 1      No
# 2       N
# 3     Yes
# 4       Y
# 5     Yes
# 6      No
# 7       N
# 8     Yes
# 9     Yes
# 10    Yes
# 11      Y
# 12    Yes
# 13    Yes
# 14      N
# 15     No
# 16    Yes
# 17      Y
# 18    N/a
# 19    Yes
# Name: Paying Customer, dtype: object

# %%
df['Paying Customer'].str.replace('N/a', '')
# Out:
# 0     Yes
# 1      No
# 2       N
# 3     Yes
# 4       Y
# 5     Yes
# 6      No
# 7       N
# 8     Yes
# 9     Yes
# 10    Yes
# 11      Y
# 12    Yes
# 13    Yes
# 14      N
# 15     No
# 16    Yes
# 17      Y
# 18
# 19    Yes
# Name: Paying Customer, dtype: object

# %%
df['Paying Customer']=df['Paying Customer'].str.replace('No', 'N')
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\1493691822.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Paying Customer']=df['Paying Customer'].str.replace('No', 'N')

# %%
df['Paying Customer']=df['Paying Customer'].str.replace('Yes', 'Y')
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\2267677481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Paying Customer']=df['Paying Customer'].str.replace('Yes', 'Y')

# %%
df['Paying Customer']
# Out:
# 0       Y
# 1       N
# 2       N
# 3       Y
# 4       Y
# 5       Y
# 6       N
# 7       N
# 8       Y
# 9       Y
# 10      Y
# 11      Y
# 12      Y
# 13      Y
# 14      N
# 15      N
# 16      Y
# 17      Y
# 18    N/a
# 19      Y
# Name: Paying Customer, dtype: object

# %%
df['Paying Customer']=df['Paying Customer'].str.replace('N/a', '')
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\3471373005.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Paying Customer']=df['Paying Customer'].str.replace('N/a', '')

# %%
df['Paying Customer']
# Out:
# 0     Y
# 1     N
# 2     N
# 3     Y
# 4     Y
# 5     Y
# 6     N
# 7     N
# 8     Y
# 9     Y
# 10    Y
# 11    Y
# 12    Y
# 13    Y
# 14    N
# 15    N
# 16    Y
# 17    Y
# 18
# 19    Y
# Name: Paying Customer, dtype: object

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 1         1002       Abed       Nadir  123-643-9775               N
# 2         1003     Walter       White                             N
# 3         1004     Dwight     Schrute  123-543-2345               Y
# 4         1005        Jon        Snow  876-678-3469               Y
# 5         1006        Ron     Swanson  304-762-2467               Y
# 6         1007       Jeff      Winger                             N
# 7         1008   Sherlock      Holmes  876-678-3469               N
# 8         1009    Gandalf                                         Y
# 9         1010      Peter      Parker  123-545-5421               Y
# 10        1011    Samwise      Gamgee                             Y
# 11        1012      Harry      Potter                             Y
# 12        1013        Don      Draper  123-543-2345               Y
# 13        1014     Leslie       Knope  876-678-3469               Y
# 14        1015       Toby  Flenderson  304-762-2467               N
# 15        1016        Ron     Weasley  123-545-5421               N
# 16        1017   Michael        Scott  123-643-9775               Y
# 17        1018      Clark        Kent                             Y
# 18        1019      Creed      Braton
# 19        1020     Anakin   Skywalker  876-678-3469               Y
#
#    Do_Not_Contact        Street_Address          State Zip_Code
# 0              No        123 Shire Lane          Shire     None
# 1             Yes   93 West Main Street           None     None
# 2             NaN    298 Drugs Driveway           None     None
# 3               Y      980 Paper Avenue   Pennsylvania    18503
# 4              No      123 Dragons Road           None     None
# 5             Yes      768 City Parkway           None     None
# 6              No     1209 South Street           None     None
# 7              No         98 Clue Drive           None     None
# 8             NaN      123 Middle Earth           None     None
# 9              No      25th Main Street       New York     None
# 10             No        612 Shire Lane          Shire     None
# 11            NaN  2394 Hogwarts Avenue           None     None
# 12              N      2039 Main Street           None     None
# 13             No      343 City Parkway           None     None
# 14             No         214 HR Avenue           None     None
# 15              N  2395 Hogwarts Avenue           None     None
# 16             No      121 Paper Avenue   Pennsylvania     None
# 17            NaN       3498 Super Lane           None     None
# 18            Yes                                 None     None
# 19              N     910 Tatooine Road       Tatooine     None

# %%
df['Do_Not_Contact']=df['Do_Not_Contact'].str.replace('Yes', 'Y')
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\2506803438.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Do_Not_Contact']=df['Do_Not_Contact'].str.replace('Yes', 'Y')

# %%
df['Do_Not_Contact']=df['Do_Not_Contact'].str.replace('No', 'N')
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\1656565943.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Do_Not_Contact']=df['Do_Not_Contact'].str.replace('No', 'N')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 1         1002       Abed       Nadir  123-643-9775               N
# 2         1003     Walter       White                             N
# 3         1004     Dwight     Schrute  123-543-2345               Y
# 4         1005        Jon        Snow  876-678-3469               Y
# 5         1006        Ron     Swanson  304-762-2467               Y
# 6         1007       Jeff      Winger                             N
# 7         1008   Sherlock      Holmes  876-678-3469               N
# 8         1009    Gandalf                                         Y
# 9         1010      Peter      Parker  123-545-5421               Y
# 10        1011    Samwise      Gamgee                             Y
# 11        1012      Harry      Potter                             Y
# 12        1013        Don      Draper  123-543-2345               Y
# 13        1014     Leslie       Knope  876-678-3469               Y
# 14        1015       Toby  Flenderson  304-762-2467               N
# 15        1016        Ron     Weasley  123-545-5421               N
# 16        1017   Michael        Scott  123-643-9775               Y
# 17        1018      Clark        Kent                             Y
# 18        1019      Creed      Braton
# 19        1020     Anakin   Skywalker  876-678-3469               Y
#
#    Do_Not_Contact        Street_Address          State Zip_Code
# 0               N        123 Shire Lane          Shire     None
# 1               Y   93 West Main Street           None     None
# 2             NaN    298 Drugs Driveway           None     None
# 3               Y      980 Paper Avenue   Pennsylvania    18503
# 4               N      123 Dragons Road           None     None
# 5               Y      768 City Parkway           None     None
# 6               N     1209 South Street           None     None
# 7               N         98 Clue Drive           None     None
# 8             NaN      123 Middle Earth           None     None
# 9               N      25th Main Street       New York     None
# 10              N        612 Shire Lane          Shire     None
# 11            NaN  2394 Hogwarts Avenue           None     None
# 12              N      2039 Main Street           None     None
# 13              N      343 City Parkway           None     None
# 14              N         214 HR Avenue           None     None
# 15              N  2395 Hogwarts Avenue           None     None
# 16              N      121 Paper Avenue   Pennsylvania     None
# 17            NaN       3498 Super Lane           None     None
# 18              Y                                 None     None
# 19              N     910 Tatooine Road       Tatooine     None

# %%
df = df.replace('N/a', '')

# %%
df = df.fillna('')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 1         1002       Abed       Nadir  123-643-9775               N
# 2         1003     Walter       White                             N
# 3         1004     Dwight     Schrute  123-543-2345               Y
# 4         1005        Jon        Snow  876-678-3469               Y
# 5         1006        Ron     Swanson  304-762-2467               Y
# 6         1007       Jeff      Winger                             N
# 7         1008   Sherlock      Holmes  876-678-3469               N
# 8         1009    Gandalf                                         Y
# 9         1010      Peter      Parker  123-545-5421               Y
# 10        1011    Samwise      Gamgee                             Y
# 11        1012      Harry      Potter                             Y
# 12        1013        Don      Draper  123-543-2345               Y
# 13        1014     Leslie       Knope  876-678-3469               Y
# 14        1015       Toby  Flenderson  304-762-2467               N
# 15        1016        Ron     Weasley  123-545-5421               N
# 16        1017   Michael        Scott  123-643-9775               Y
# 17        1018      Clark        Kent                             Y
# 18        1019      Creed      Braton
# 19        1020     Anakin   Skywalker  876-678-3469               Y
#
#    Do_Not_Contact        Street_Address          State Zip_Code
# 0               N        123 Shire Lane          Shire
# 1               Y   93 West Main Street
# 2                    298 Drugs Driveway
# 3               Y      980 Paper Avenue   Pennsylvania    18503
# 4               N      123 Dragons Road
# 5               Y      768 City Parkway
# 6               N     1209 South Street
# 7               N         98 Clue Drive
# 8                      123 Middle Earth
# 9               N      25th Main Street       New York
# 10              N        612 Shire Lane          Shire
# 11                 2394 Hogwarts Avenue
# 12              N      2039 Main Street
# 13              N      343 City Parkway
# 14              N         214 HR Avenue
# 15              N  2395 Hogwarts Avenue
# 16              N      121 Paper Avenue   Pennsylvania
# 17                      3498 Super Lane
# 18              Y
# 19              N     910 Tatooine Road       Tatooine

# %%
# Ask: Give the list of only those customers whome we can call

for x in df.index:
    if df.loc[x, 'Do_Not_Contact'] == 'Y':
        df.drop(x, inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 2         1003     Walter       White                             N
# 4         1005        Jon        Snow  876-678-3469               Y
# 6         1007       Jeff      Winger                             N
# 7         1008   Sherlock      Holmes  876-678-3469               N
# 8         1009    Gandalf                                         Y
# 9         1010      Peter      Parker  123-545-5421               Y
# 10        1011    Samwise      Gamgee                             Y
# 11        1012      Harry      Potter                             Y
# 12        1013        Don      Draper  123-543-2345               Y
# 13        1014     Leslie       Knope  876-678-3469               Y
# 14        1015       Toby  Flenderson  304-762-2467               N
# 15        1016        Ron     Weasley  123-545-5421               N
# 16        1017   Michael        Scott  123-643-9775               Y
# 17        1018      Clark        Kent                             Y
# 19        1020     Anakin   Skywalker  876-678-3469               Y
#
#    Do_Not_Contact        Street_Address          State Zip_Code
# 0               N        123 Shire Lane          Shire
# 2                    298 Drugs Driveway
# 4               N      123 Dragons Road
# 6               N     1209 South Street
# 7               N         98 Clue Drive
# 8                      123 Middle Earth
# 9               N      25th Main Street       New York
# 10              N        612 Shire Lane          Shire
# 11                 2394 Hogwarts Avenue
# 12              N      2039 Main Street
# 13              N      343 City Parkway
# 14              N         214 HR Avenue
# 15              N  2395 Hogwarts Avenue
# 16              N      121 Paper Avenue   Pennsylvania
# 17                      3498 Super Lane
# 19              N     910 Tatooine Road       Tatooine

# %%
df["Do_Not_Contact"].str.replace('', 'N')
# Out:
# 0     NNN
# 2       N
# 4     NNN
# 6     NNN
# 7     NNN
# 8       N
# 9     NNN
# 10    NNN
# 11      N
# 12    NNN
# 13    NNN
# 14    NNN
# 15    NNN
# 16    NNN
# 17      N
# 19    NNN
# Name: Do_Not_Contact, dtype: object

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.strip()

# %%
df["Do_Not_Contact"].str.replace('', 'N')
# Out:
# 0     NNN
# 2       N
# 4     NNN
# 6     NNN
# 7     NNN
# 8       N
# 9     NNN
# 10    NNN
# 11      N
# 12    NNN
# 13    NNN
# 14    NNN
# 15    NNN
# 16    NNN
# 17      N
# 19    NNN
# Name: Do_Not_Contact, dtype: object

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 2         1003     Walter       White                             N
# 4         1005        Jon        Snow  876-678-3469               Y
# 6         1007       Jeff      Winger                             N
# 7         1008   Sherlock      Holmes  876-678-3469               N
# 8         1009    Gandalf                                         Y
# 9         1010      Peter      Parker  123-545-5421               Y
# 10        1011    Samwise      Gamgee                             Y
# 11        1012      Harry      Potter                             Y
# 12        1013        Don      Draper  123-543-2345               Y
# 13        1014     Leslie       Knope  876-678-3469               Y
# 14        1015       Toby  Flenderson  304-762-2467               N
# 15        1016        Ron     Weasley  123-545-5421               N
# 16        1017   Michael        Scott  123-643-9775               Y
# 17        1018      Clark        Kent                             Y
# 19        1020     Anakin   Skywalker  876-678-3469               Y
#
#    Do_Not_Contact        Street_Address          State Zip_Code
# 0               N        123 Shire Lane          Shire
# 2                    298 Drugs Driveway
# 4               N      123 Dragons Road
# 6               N     1209 South Street
# 7               N         98 Clue Drive
# 8                      123 Middle Earth
# 9               N      25th Main Street       New York
# 10              N        612 Shire Lane          Shire
# 11                 2394 Hogwarts Avenue
# 12              N      2039 Main Street
# 13              N      343 City Parkway
# 14              N         214 HR Avenue
# 15              N  2395 Hogwarts Avenue
# 16              N      121 Paper Avenue   Pennsylvania
# 17                      3498 Super Lane
# 19              N     910 Tatooine Road       Tatooine

# %%
# Ask: Give the list of only those customers whome we can call

for x in df.index:
    if df.loc[x, 'Phone_Number'] == '':
        df.drop(x, inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 4         1005        Jon        Snow  876-678-3469               Y
# 7         1008   Sherlock      Holmes  876-678-3469               N
# 9         1010      Peter      Parker  123-545-5421               Y
# 12        1013        Don      Draper  123-543-2345               Y
# 13        1014     Leslie       Knope  876-678-3469               Y
# 14        1015       Toby  Flenderson  304-762-2467               N
# 15        1016        Ron     Weasley  123-545-5421               N
# 16        1017   Michael        Scott  123-643-9775               Y
# 19        1020     Anakin   Skywalker  876-678-3469               Y
#
#    Do_Not_Contact        Street_Address          State Zip_Code
# 0               N        123 Shire Lane          Shire
# 4               N      123 Dragons Road
# 7               N         98 Clue Drive
# 9               N      25th Main Street       New York
# 12              N      2039 Main Street
# 13              N      343 City Parkway
# 14              N         214 HR Avenue
# 15              N  2395 Hogwarts Avenue
# 16              N      121 Paper Avenue   Pennsylvania
# 19              N     910 Tatooine Road       Tatooine

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 4         1005        Jon        Snow  876-678-3469               Y
# 7         1008   Sherlock      Holmes  876-678-3469               N
# 9         1010      Peter      Parker  123-545-5421               Y
# 12        1013        Don      Draper  123-543-2345               Y
# 13        1014     Leslie       Knope  876-678-3469               Y
# 14        1015       Toby  Flenderson  304-762-2467               N
# 15        1016        Ron     Weasley  123-545-5421               N
# 16        1017   Michael        Scott  123-643-9775               Y
# 19        1020     Anakin   Skywalker  876-678-3469               Y
#
#    Do_Not_Contact        Street_Address          State Zip_Code
# 0               N        123 Shire Lane          Shire
# 4               N      123 Dragons Road
# 7               N         98 Clue Drive
# 9               N      25th Main Street       New York
# 12              N      2039 Main Street
# 13              N      343 City Parkway
# 14              N         214 HR Avenue
# 15              N  2395 Hogwarts Avenue
# 16              N      121 Paper Avenue   Pennsylvania
# 19              N     910 Tatooine Road       Tatooine

# %%
# Let's reset the index so the end user is not confused
df = df.reset_index(drop=True)

# %%
df
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0        1001      Frodo     Baggins  123-545-5421               Y
# 1        1005        Jon        Snow  876-678-3469               Y
# 2        1008   Sherlock      Holmes  876-678-3469               N
# 3        1010      Peter      Parker  123-545-5421               Y
# 4        1013        Don      Draper  123-543-2345               Y
# 5        1014     Leslie       Knope  876-678-3469               Y
# 6        1015       Toby  Flenderson  304-762-2467               N
# 7        1016        Ron     Weasley  123-545-5421               N
# 8        1017   Michael        Scott  123-643-9775               Y
# 9        1020     Anakin   Skywalker  876-678-3469               Y
#
#   Do_Not_Contact        Street_Address          State Zip_Code
# 0              N        123 Shire Lane          Shire
# 1              N      123 Dragons Road
# 2              N         98 Clue Drive
# 3              N      25th Main Street       New York
# 4              N      2039 Main Street
# 5              N      343 City Parkway
# 6              N         214 HR Avenue
# 7              N  2395 Hogwarts Avenue
# 8              N      121 Paper Avenue   Pennsylvania
# 9              N     910 Tatooine Road       Tatooine

# %%
df.index = df.index + 1

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 1         1001      Frodo     Baggins  123-545-5421               Y
# 2         1005        Jon        Snow  876-678-3469               Y
# 3         1008   Sherlock      Holmes  876-678-3469               N
# 4         1010      Peter      Parker  123-545-5421               Y
# 5         1013        Don      Draper  123-543-2345               Y
# 6         1014     Leslie       Knope  876-678-3469               Y
# 7         1015       Toby  Flenderson  304-762-2467               N
# 8         1016        Ron     Weasley  123-545-5421               N
# 9         1017   Michael        Scott  123-643-9775               Y
# 10        1020     Anakin   Skywalker  876-678-3469               Y
#
#    Do_Not_Contact        Street_Address          State Zip_Code
# 1               N        123 Shire Lane          Shire
# 2               N      123 Dragons Road
# 3               N         98 Clue Drive
# 4               N      25th Main Street       New York
# 5               N      2039 Main Street
# 6               N      343 City Parkway
# 7               N         214 HR Avenue
# 8               N  2395 Hogwarts Avenue
# 9               N      121 Paper Avenue   Pennsylvania
# 10              N     910 Tatooine Road       Tatooine

# %%
# Ask: Give the list of only those customers whome we can call

for x in df.index:
    if df.loc[x, 'Phone_Number'] == '':
        df.drop(x, inplace=True)
df


# Another way to drop the Null values
# df = df.dropna(subset="Phone_Number"), inplace=True
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 1         1001      Frodo     Baggins  123-545-5421               Y
# 2         1005        Jon        Snow  876-678-3469               Y
# 3         1008   Sherlock      Holmes  876-678-3469               N
# 4         1010      Peter      Parker  123-545-5421               Y
# 5         1013        Don      Draper  123-543-2345               Y
# 6         1014     Leslie       Knope  876-678-3469               Y
# 7         1015       Toby  Flenderson  304-762-2467               N
# 8         1016        Ron     Weasley  123-545-5421               N
# 9         1017   Michael        Scott  123-643-9775               Y
# 10        1020     Anakin   Skywalker  876-678-3469               Y
#
#    Do_Not_Contact        Street_Address          State Zip_Code
# 1               N        123 Shire Lane          Shire
# 2               N      123 Dragons Road
# 3               N         98 Clue Drive
# 4               N      25th Main Street       New York
# 5               N      2039 Main Street
# 6               N      343 City Parkway
# 7               N         214 HR Avenue
# 8               N  2395 Hogwarts Avenue
# 9               N      121 Paper Avenue   Pennsylvania
# 10              N     910 Tatooine Road       Tatooine

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 1         1001      Frodo     Baggins  123-545-5421               Y
# 2         1005        Jon        Snow  876-678-3469               Y
# 3         1008   Sherlock      Holmes  876-678-3469               N
# 4         1010      Peter      Parker  123-545-5421               Y
# 5         1013        Don      Draper  123-543-2345               Y
# 6         1014     Leslie       Knope  876-678-3469               Y
# 7         1015       Toby  Flenderson  304-762-2467               N
# 8         1016        Ron     Weasley  123-545-5421               N
# 9         1017   Michael        Scott  123-643-9775               Y
# 10        1020     Anakin   Skywalker  876-678-3469               Y
#
#    Do_Not_Contact        Street_Address          State Zip_Code
# 1               N        123 Shire Lane          Shire
# 2               N      123 Dragons Road
# 3               N         98 Clue Drive
# 4               N      25th Main Street       New York
# 5               N      2039 Main Street
# 6               N      343 City Parkway
# 7               N         214 HR Avenue
# 8               N  2395 Hogwarts Avenue
# 9               N      121 Paper Avenue   Pennsylvania
# 10              N     910 Tatooine Road       Tatooine

# %%
df['First_Name']=df['First_Name'].str.strip()

# %%
df['Last_Name']=df['Last_Name'].str.strip()

# %%
df['Name'] = df[['First_Name', 'Last_Name']].agg(' '.join, axis=1)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 1         1001      Frodo     Baggins  123-545-5421               Y
# 2         1005        Jon        Snow  876-678-3469               Y
# 3         1008   Sherlock      Holmes  876-678-3469               N
# 4         1010      Peter      Parker  123-545-5421               Y
# 5         1013        Don      Draper  123-543-2345               Y
# 6         1014     Leslie       Knope  876-678-3469               Y
# 7         1015       Toby  Flenderson  304-762-2467               N
# 8         1016        Ron     Weasley  123-545-5421               N
# 9         1017    Michael       Scott  123-643-9775               Y
# 10        1020     Anakin   Skywalker  876-678-3469               Y
#
#    Do_Not_Contact        Street_Address          State Zip_Code  \
# 1               N        123 Shire Lane          Shire
# 2               N      123 Dragons Road
# 3               N         98 Clue Drive
# 4               N      25th Main Street       New York
# 5               N      2039 Main Street
# 6               N      343 City Parkway
# 7               N         214 HR Avenue
# 8               N  2395 Hogwarts Avenue
# 9               N      121 Paper Avenue   Pennsylvania
# 10              N     910 Tatooine Road       Tatooine
#
#                 Name
# 1      Frodo Baggins
# 2           Jon Snow
# 3    Sherlock Holmes
# 4       Peter Parker
# 5         Don Draper
# 6       Leslie Knope
# 7    Toby Flenderson
# 8        Ron Weasley
# 9      Michael Scott
# 10  Anakin Skywalker

# %%
df.drop(columns = ["First_Name", 'Last_Name'], inplace=True)

# %%
df
# Out:
#     CustomerID  Phone_Number Paying Customer Do_Not_Contact  \
# 1         1001  123-545-5421               Y              N
# 2         1005  876-678-3469               Y              N
# 3         1008  876-678-3469               N              N
# 4         1010  123-545-5421               Y              N
# 5         1013  123-543-2345               Y              N
# 6         1014  876-678-3469               Y              N
# 7         1015  304-762-2467               N              N
# 8         1016  123-545-5421               N              N
# 9         1017  123-643-9775               Y              N
# 10        1020  876-678-3469               Y              N
#
#           Street_Address          State Zip_Code              Name
# 1         123 Shire Lane          Shire              Frodo Baggins
# 2       123 Dragons Road                                  Jon Snow
# 3          98 Clue Drive                           Sherlock Holmes
# 4       25th Main Street       New York               Peter Parker
# 5       2039 Main Street                                Don Draper
# 6       343 City Parkway                              Leslie Knope
# 7          214 HR Avenue                           Toby Flenderson
# 8   2395 Hogwarts Avenue                               Ron Weasley
# 9       121 Paper Avenue   Pennsylvania              Michael Scott
# 10     910 Tatooine Road       Tatooine           Anakin Skywalker

# %%
df.head(2)
# Out:
#    CustomerID  Phone_Number Paying Customer Do_Not_Contact    Street_Address  \
# 1        1001  123-545-5421               Y              N    123 Shire Lane
# 2        1005  876-678-3469               Y              N  123 Dragons Road
#
#     State Zip_Code           Name
# 1   Shire           Frodo Baggins
# 2                        Jon Snow

# %%
df = df[["CustomerID", "Name", "Phone_Number", "Paying Customer", "Do_Not_Contact", "Street_Address", "State", "Zip_Code"]]

# %%
df["Customer_Name"] = df["Name"]
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13336\2394863932.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Customer_Name"] = df["Name"]

# %%
df = df = df[["CustomerID", "Customer_Name", "Phone_Number", "Paying Customer", "Do_Not_Contact", "Street_Address", "State", "Zip_Code"]]

# %%
df
# Out:
#     CustomerID     Customer_Name  Phone_Number Paying Customer Do_Not_Contact  \
# 1         1001     Frodo Baggins  123-545-5421               Y              N
# 2         1005          Jon Snow  876-678-3469               Y              N
# 3         1008   Sherlock Holmes  876-678-3469               N              N
# 4         1010      Peter Parker  123-545-5421               Y              N
# 5         1013        Don Draper  123-543-2345               Y              N
# 6         1014      Leslie Knope  876-678-3469               Y              N
# 7         1015   Toby Flenderson  304-762-2467               N              N
# 8         1016       Ron Weasley  123-545-5421               N              N
# 9         1017     Michael Scott  123-643-9775               Y              N
# 10        1020  Anakin Skywalker  876-678-3469               Y              N
#
#           Street_Address          State Zip_Code
# 1         123 Shire Lane          Shire
# 2       123 Dragons Road
# 3          98 Clue Drive
# 4       25th Main Street       New York
# 5       2039 Main Street
# 6       343 City Parkway
# 7          214 HR Avenue
# 8   2395 Hogwarts Avenue
# 9       121 Paper Avenue   Pennsylvania
# 10     910 Tatooine Road       Tatooine
